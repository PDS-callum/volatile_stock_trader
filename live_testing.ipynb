# %%
from src.stock_bot.strategy_tester import StrategyTester

# %%
tester = StrategyTester(
    "AVGO", 
    period="30d",
    interval="15m", 
    min_points=40
)
tester.run(closed_market=True, updates=1500)

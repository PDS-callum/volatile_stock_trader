# %%
from src.stock_bot.__main__ import run_strategy_core

# %%
run_strategy_core(
    "IONQ",
    12, 26, 9, 14, 5, 20,
    "60d", "15m",
    False, True,
    notebook=True
)

# %%
run_strategy_core(
    "CRWD",
    12, 26, 9, 14, 5, 20,
    "60d", "15m",
    False, True,
    notebook=True
)

# %%
run_strategy_core(
    "SNGX",
    12, 26, 9, 14, 5, 20,
    "60d", "15m",
    False, True,
    notebook=True
)

# %%
run_strategy_core(
    "AVGO",
    12, 26, 9, 14, 5, 20,
    "60d", "15m",
    False, True,
    notebook=True
)
